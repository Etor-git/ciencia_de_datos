# %% [markdown]
# <a href="https://colab.research.google.com/github/Etor-git/ciencia_de_datos/blob/main/Transformaciones%20y%20Transposici%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

#Crear un elemento
arr = np.arange(15).reshape((3, 5))
print("Forma original:", arr.shape) # (3, 5)
# Obtener la transpuesta usando el atributo .T
arr_t = arr.T
print("Forma de la transpuesta:", arr_t.shape) # Debe ser (5, 3)
# Out:
# Forma original: (3, 5)
# Forma de la transpuesta: (5, 3)
