# %% [markdown]
# <a href="https://colab.research.google.com/github/Etor-git/ciencia_de_datos/blob/main/%C3%81lgebra%20Lineal%20B%C3%A1sica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
rng = np.random.default_rng()
X = rng.standard_normal((2, 3))
# Multiplicación de matriz por su transpuesta usando el operador @
resultado = X @ X.T
print("Resultado de X multiplicado por X transpuesta:\n", resultado)
# Alternativa usando np.dot
resultado_dot = np.dot(X, X.T)
# Out:
# Resultado de X multiplicado por X transpuesta:
#  [[ 1.86037341 -2.37943971]
#  [-2.37943971  6.53344183]]
