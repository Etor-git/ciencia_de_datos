# %% [markdown]
# <a href="https://colab.research.google.com/github/Etor-git/ciencia_de_datos/blob/main/Valores%20%C3%9Anicos%20y%20Ordenamiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

datos = np.array([100, 12, 30, 4, 34])
# np.unique devuelve los valores únicos ya ordenados
unicos = np.unique(datos)
print("Valores únicos ordenados:", unicos)
# Out:
# Valores únicos ordenados: [  4  12  30  34 100]
