# %% [markdown]
# <a href="https://colab.research.google.com/github/Etor-git/ciencia_de_datos/blob/main/Filtrado%20L%C3%B3gico%20Complejo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

arr = np.arange(1, 21)
# Crear la máscara booleana combinando condiciones con &
mask = (arr > 10) & (arr % 2 == 0)
resultado = arr[mask]
print("Números > 10 y pares:", resultado)
# Out:
# Números > 10 y pares: [12 14 16 18 20]
